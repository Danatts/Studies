# %% [markdown]
# # Ejercicio Diabetes

# %% [markdown]
# ## Importar librerias

# %%
# Importar librerias
import numpy as np
import pandas as pd

# %% [markdown]
# ## Cargar datos

# %%
base = pd.read_csv('./diabetic_data.csv')
base.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %% [markdown]
# ## Indexar identificadores

# %%
base.set_index(['encounter_id', 'patient_nbr'], inplace=True)
base.head()
# Out:
#                                      race  gender      age weight  \
# encounter_id patient_nbr
# 2278392      8222157            Caucasian  Female   [0-10)      ?
# 149190       55629189           Caucasian  Female  [10-20)      ?
# 64410        86047875     AfricanAmerican  Female  [20-30)      ?
# 500364       82442376           Caucasian    Male  [30-40)      ?
# 16680        42519267           Caucasian    Male  [40-50)      ?
#
#                           admission_type_id  discharge_disposition_id  \
# encounter_id patient_nbr
# 2278392      8222157                      6                        25
# 149190       55629189                     1                         1
# 64410        86047875                     1                         1
# 500364       82442376                     1                         1
# 16680        42519267                     1                         1
#
#                           admission_source_id  time_in_hospital payer_code  \
# ...

# %% [markdown]
# ## Navegar por los datos

# %%
# Información general de la tabla 
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 101766 entries, (2278392, 8222157) to (443867222, 175429310)
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      101766 non-null  object
#  1   gender                    101766 non-null  object
#  2   age                       101766 non-null  object
#  3   weight                    101766 non-null  object
#  4   admission_type_id         101766 non-null  int64
#  5   discharge_disposition_id  101766 non-null  int64
#  6   admission_source_id       101766 non-null  int64
#  7   time_in_hospital          101766 non-null  int64
#  8   payer_code                101766 non-null  object
#  9   medical_specialty         101766 non-null  object
#  10  num_lab_procedures        101766 non-null  int64
#  11  num_procedures            101766 non-null  int64
#  12  num_medications           101766 non-null  int64
# ...

# %%
# n registros aleatorios de la tabla
base.sample(n=10)
# Out:
#                                race  gender      age weight  \
# encounter_id patient_nbr
# 221243220    41439285     Caucasian    Male  [70-80)      ?
# 243111438    69022107     Caucasian    Male  [80-90)      ?
# 421469618    35640126     Caucasian  Female  [70-80)      ?
# 27337488     242784       Caucasian  Female  [70-80)      ?
# 76692600     112088349    Caucasian  Female  [80-90)      ?
# 142741146    55752714     Caucasian  Female  [80-90)      ?
# 132004758    44182620     Caucasian    Male  [40-50)      ?
# 173522052    89948745     Caucasian    Male  [60-70)      ?
# 62995044     1098162      Caucasian    Male  [70-80)      ?
# 113255136    104331906     Hispanic  Female  [70-80)      ?
#
#                           admission_type_id  discharge_disposition_id  \
# encounter_id patient_nbr
# 221243220    41439285                     1                         1
# 243111438    69022107                     3                         1
# ...

# %%
# Tamaño de la tabla (filas x columnas)
base.shape
# Out:
# (101766, 48)

# %%
# Consultar una columna
base['age']
# Out:
# encounter_id  patient_nbr
# 2278392       8222157         [0-10)
# 149190        55629189       [10-20)
# 64410         86047875       [20-30)
# 500364        82442376       [30-40)
# 16680         42519267       [40-50)
#                               ...
# 443847548     100162476      [70-80)
# 443847782     74694222       [80-90)
# 443854148     41088789       [70-80)
# 443857166     31693671       [80-90)
# 443867222     175429310      [70-80)
# Name: age, Length: 101766, dtype: object

# %%
# Consultar información de un registro por index
base.loc[27337488]
# Out:
#                   race  gender      age weight  admission_type_id  \
# patient_nbr
# 242784       Caucasian  Female  [70-80)      ?                  1
#
#              discharge_disposition_id  admission_source_id  time_in_hospital  \
# patient_nbr
# 242784                              6                    7                11
#
#             payer_code medical_specialty  ...  citoglipton  insulin  \
# patient_nbr                               ...
# 242784               ?                 ?  ...           No       No
#
#              glyburide-metformin  glipizide-metformin  \
# patient_nbr
# 242784                        No                   No
#
#              glimepiride-pioglitazone  metformin-rosiglitazone  \
# patient_nbr
# 242784                             No                       No
#
#             metformin-pioglitazone change diabetesMed  readmitted
# patient_nbr
# 242784                          No     Ch         Yes         >30
#
# [1 rows x 48 columns]

# %%
# Consultar información de un registro por ubicación
base.iloc[10]
# Out:
# race                        AfricanAmerican
# gender                               Female
# age                                 [40-50)
# weight                                    ?
# admission_type_id                         1
# discharge_disposition_id                  1
# admission_source_id                       7
# time_in_hospital                          9
# payer_code                                ?
# medical_specialty                         ?
# num_lab_procedures                       47
# num_procedures                            2
# num_medications                          17
# number_outpatient                         0
# number_emergency                          0
# number_inpatient                          0
# diag_1                                250.7
# diag_2                                  403
# diag_3                                  996
# number_diagnoses                          9
# max_glu_serum                           NaN
# ...

# %% [markdown]
# ## Etiquetar datos

# %%
admission_type_id_1 = {
    1:"Emergency",
    2:"Urgent",
    3:"Elective",
    4:"Newborn",
    5:"Not Available",
    6:"NULL",
    7:"Trauma Center",
    8:"Not Mapped"
}
