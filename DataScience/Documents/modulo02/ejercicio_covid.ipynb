# %% [markdown]
# # Ejercicio Covid

# %%
import pandas as pd

# %%
base = pd.read_csv('casos_covid.csv')
base.head()
# Out:
#    ID de caso Fecha de diagnóstico Ciudad de ubicación  \
# 0           1           06/03/2020              Bogotá
# 1           2           09/03/2020                Buga
# 2           3           09/03/2020            Medellín
# 3           4           11/03/2020            Medellín
# 4           5           11/03/2020            Medellín
#
#   Departamento o Distrito  Atención**  Edad Sexo        Tipo*  \
# 0             Bogotá D.C.  Recuperado    19    F    Importado
# 1         Valle del Cauca  Recuperado    34    M    Importado
# 2               Antioquia  Recuperado    50    F    Importado
# 3               Antioquia  Recuperado    55    M  Relacionado
# 4               Antioquia  Recuperado    25    M  Relacionado
#
#   País de procedencia
# 0              Italia
# 1              España
# 2              España
# 3            Colombia
# 4            Colombia

# %%
base.set_index('ID de caso', inplace = True)
base.head()
# Out:
#            Fecha de diagnóstico Ciudad de ubicación Departamento o Distrito  \
# ID de caso
# 1                    06/03/2020              Bogotá             Bogotá D.C.
# 2                    09/03/2020                Buga         Valle del Cauca
# 3                    09/03/2020            Medellín               Antioquia
# 4                    11/03/2020            Medellín               Antioquia
# 5                    11/03/2020            Medellín               Antioquia
#
#             Atención**  Edad Sexo        Tipo* País de procedencia
# ID de caso
# 1           Recuperado    19    F    Importado              Italia
# 2           Recuperado    34    M    Importado              España
# 3           Recuperado    50    F    Importado              España
# 4           Recuperado    55    M  Relacionado            Colombia
# 5           Recuperado    25    M  Relacionado            Colombia

# %%
base.dtypes
# Out:
# Fecha de diagnóstico       object
# Ciudad de ubicación        object
# Departamento o Distrito    object
# Atención**                 object
# Edad                        int64
# Sexo                       object
# Tipo*                      object
# País de procedencia        object
# dtype: object

# %%
base['Fecha de diagnóstico'] = pd.to_datetime(base['Fecha de diagnóstico'], format="%d/%m/%Y")
base.dtypes
# Out:
# Fecha de diagnóstico       datetime64[ns]
# Ciudad de ubicación                object
# Departamento o Distrito            object
# Atención**                         object
# Edad                                int64
# Sexo                               object
# Tipo*                              object
# País de procedencia                object
# dtype: object

# %%
base.groupby('Ciudad de ubicación').count().sort_values('Atención**')
# Out:
#                      Fecha de diagnóstico  Departamento o Distrito  \
# Ciudad de ubicación
# Montebello                              1                        1
# Guarne                                  1                        1
# Guatapé                                 1                        1
# Ipiales                                 1                        1
# La Calera                               1                        1
# ...                                   ...                      ...
# Barranquilla                           31                       31
# Cartagena                              39                       39
# Medellín                               86                       86
# Cali                                  104                      104
# Bogotá                                542                      542
#
#                      Atención**  Edad  Sexo  Tipo*  País de procedencia
# Ciudad de ubicación
# ...

# %%
base[(base['Edad'] > 60) & (base['País de procedencia'] == 'Estados Unidos')]
# Out:
#            Fecha de diagnóstico Ciudad de ubicación Departamento o Distrito  \
# ID de caso
# 7                    2020-03-11           Cartagena      Cartagena D.T. y C
# 31                   2020-03-15           Manizales                  Caldas
# 36                   2020-03-15              Bogotá             Bogotá D.C.
# 110                  2020-03-19              Bogotá             Bogotá D.C.
# 152                  2020-03-20              Bogotá             Bogotá D.C.
# 189                  2020-03-21                Cali         Valle del Cauca
# 195                  2020-03-21             Pereira               Risaralda
# 223                  2020-03-22             Pereira               Risaralda
# 303                  2020-03-23              Itagüí               Antioquia
# 361                  2020-03-24       Villavicencio                    Meta
# 372                  2020-03-24           Manizales                  Caldas
# ...
