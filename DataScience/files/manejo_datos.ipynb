# %% [markdown]
# # Operaciones de Manejo de Datos

# %% [markdown]
# ## Cirugía de datos

# %% [markdown]
# La gestión de datos describe una serie de procesos diseñados para explorar, transformar y validar conjuntos de datos sin procesar desde sus formas desordenadas y complejas hasta datos de alta calidad. Los datos procesados pueden utilizarse para obtener información valiosa y orientar las decisiones empresariales.

# %%
import pandas as pd

# %%
# Adapatmos los datos para que puedan ser leidos como csv
with open('../datasets/customer_churn/customer_churn.csv', 'r') as infile:
    with open('../datasets/customer_churn/customer_churn_fixed.csv', 'w') as outfile:
        for line in infile:
            new_line = line.replace('\"', '')
            outfile.write(new_line)

# %%
df = pd.read_csv('../datasets/customer_churn/customer_churn_fixed.csv', sep = ',')
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Crear un subconjutnto de columnas

# %%
# Seleccionar una única columna
df['Account Length']
# Out:
# 0       128
# 1       107
# 2       137
# 3        84
# 4        75
#        ...
# 3328    192
# 3329     68
# 3330     28
# 3331    184
# 3332     74
# Name: Account Length, Length: 3333, dtype: int64

# %%
# Seleccionar varias columnas
df[['Account Length', 'Phone', 'Eve Charge', 'Day Calls']]
# Out:
#       Account Length     Phone  Eve Charge  Day Calls
# 0                128  382-4657       16.78        110
# 1                107  371-7191       16.62        123
# 2                137  358-1921       10.30        114
# 3                 84  375-9999        5.26         71
# 4                 75  330-6626       12.61        113
# ...              ...       ...         ...        ...
# 3328             192  414-4276       18.32         77
# 3329              68  370-3271       13.04         57
# 3330              28  328-8230       24.55        109
# 3331             184  364-6381       13.57        105
# 3332              74  400-4344       22.60        113
#
# [3333 rows x 4 columns]

# %% [markdown]
# ## Crear subconjuntos de filas

# %%
# Seleccionar un rango de datos
df.iloc[10:20]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# 13    MT              95        510  394-8006         no         no
# 14    IA              62        415  366-9238         no         no
# 15    NY             161        415  351-7269         no         no
# 16    ID              85        408  350-8884         no        yes
# 17    VT              93        510  386-2923         no         no
# 18    VA              76        510  356-2992         no        yes
# 19    TX              73        415  373-2782         no         no
#
#     VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 10              0     129.1        137       21.95  ...         83
# 11              0     187.7        127       31.91  ...        148
# 12              0     128.8         96       21.90  ...         71
# 13              0     156.6         88       26.62  ...         75
# 14              0     120.7         70       20.52  ...         76
# 15              0     332.9         67       56.59  ...         97
# 16             27     196.4        139       33.39  ...         90
# 17              0     190.7        114       32.42  ...        111
# 18             33     189.7         66       32.25  ...         65
# 19              0     224.4         90       38.15  ...         88
#
#     Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 10       19.42       208.8          111          9.40       12.7           6
# 11       13.89       196.0           94          8.82        9.1           5
# 12        8.92       141.1          128          6.35       11.2           2
# 13       21.05       192.3          115          8.65       12.3           5
# 14       26.11       203.0           99          9.14       13.1           6
# 15       27.01       160.6          128          7.23        5.4           9
# 16       23.88        89.3           75          4.02       13.8           4
# 17       18.55       129.6          121          5.83        8.1           3
# 18       18.09       165.7          108          7.46       10.0           5
# 19       13.56       192.8           74          8.68       13.0           2
#
#     Intl Charge  CustServ Calls  Churn?
# 10         3.43               4   True.
# 11         2.46               0  False.
# 12         3.02               1  False.
# 13         3.32               3  False.
# 14         3.54               4  False.
# 15         1.46               4   True.
# 16         3.73               1  False.
# 17         2.19               3  False.
# 18         2.70               1  False.
# 19         3.51               1  False.
#
# [10 rows x 21 columns]

# %%
# Seleccionar por etiquetas
df.loc[df['Day Mins'] > 325]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 156     OH              83        415  370-9116         no         no
# 197     TX             208        510  378-3625         no         no
# 365     CO             154        415  343-5709         no         no
# 605     MO             112        415  373-2053         no         no
# 975     DE             129        510  332-6181         no         no
# 985     NY              64        415  345-9140        yes         no
# 1679    OK              82        510  393-4823         no         no
# 2028    SD              93        510  408-4836         no         no
# 2412    WI              89        415  373-4264         no         no
# 2594    OH             115        510  348-1163        yes         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15                0     332.9         67       56.59  ...         97
# 156               0     337.4        120       57.36  ...        116
# 197               0     326.5         67       55.51  ...        113
# 365               0     350.8         75       59.64  ...         94
# 605               0     335.5         77       57.04  ...        109
# 975               0     334.3        118       56.83  ...        104
# 985               0     346.8         55       58.96  ...         79
# 1679              0     329.8         73       56.07  ...        120
# 2028              0     328.1        106       55.78  ...         89
# 2412              0     326.3        112       55.47  ...        110
# 2594              0     345.3         81       58.70  ...        106
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 15         27.01       160.6          128          7.23        5.4
# 156        19.33       153.9          114          6.93       15.8
# 197        14.99       181.7          102          8.18       10.7
# 365        18.40       253.9          100         11.43       10.1
# 605        18.06       265.0          132         11.93       12.7
# 975        16.33       191.0           83          8.59       10.4
# 985        21.21       275.4          102         12.39       13.3
# 1679       17.71       267.1          102         12.02       10.6
# 2028       12.89       303.5          114         13.66        8.7
# 2412       14.03       162.9           97          7.33        7.5
# 2594       17.29       217.5          107          9.79       11.8
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 15             9         1.46               4   True.
# 156            7         4.27               0   True.
# 197            6         2.89               2   True.
# 365            9         2.73               1   True.
# 605            8         3.43               2   True.
# 975            6         2.81               0   True.
# 985            9         3.59               1   True.
# 1679           6         2.86               0   True.
# 2028           3         2.35               1   True.
# 2412           1         2.03               1   True.
# 2594           8         3.19               1   True.
#
# [11 rows x 21 columns]

# %% [markdown]
# ## Crear subconjuntos de filas y columnas

# %%
# Seleccionar por etiquetas (filas, columnas)
df.loc[100:115, ['Day Mins', 'Night Mins', 'Eve Calls']]
# Out:
#      Day Mins  Night Mins  Eve Calls
# 100     161.2       160.2         83
# 101     178.3       129.1         76
# 102     151.7       180.0        105
# 103     135.0       245.3        106
# 104     170.5       248.6        109
# 105     238.1       190.0         98
# 106     281.4       187.2         76
# 107     117.9       217.0        115
# 108     148.6       219.4         97
# 109     229.8       241.4        121
# 110     165.0       119.2         83
# 111     185.0       222.8         94
# 112     161.0       227.7        113
# 113     126.7       247.8         90
# 114      58.9       211.4         59
# 115     196.8       138.3        122

# %%
# Seleccioanr por índices (filas, columnas)
df.iloc[1:10, 3:6]
# Out:
#       Phone Int'l Plan VMail Plan
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %% [markdown]
# ## Agrupación de datos

# %%
df.groupby('State')

# %%
df.groupby('State').groups
# Out:
# {'AK': [36, 38, 95, 138, 181, 282, 339, 350, 353, 505, 550, 657, 684, 718, 719, 812, 950, 953, 1024, 1054, 1094, 1162, 1224, 1260, 1342, 1417, 1589, 1682, 1803, 1884, 1987, 2071, 2083, 2101, 2222, 2265, 2269, 2270, 2367, 2418, 2475, 2571, 2627, 2752, 2807, 2902, 2929, 3088, 3137, 3236, 3241, 3283], 'AL': [5, 112, 135, 169, 219, 239, 272, 278, 288, 326, 332, 450, 469, 491, 497, 514, 531, 540, 590, 750, 776, 788, 805, 822, 843, 859, 934, 949, 958, 1015, 1026, 1090, 1104, 1129, 1131, 1152, 1274, 1428, 1464, 1613, 1661, 1662, 1767, 1780, 1839, 1902, 2081, 2135, 2155, 2172, 2180, 2212, 2317, 2329, 2334, 2348, 2446, 2494, 2595, 2601, 2634, 2644, 2699, 2738, 2748, 2749, 2827, 2845, 2858, 2939, 2992, 3017, 3048, 3058, 3078, 3095, 3128, 3139, 3180, 3306], 'AR': [42, 92, 134, 178, 297, 351, 352, 440, 442, 475, 585, 652, 696, 911, 956, 960, 1023, 1226, 1320, 1484, 1536, 1543, 1596, 1601, 1639, 1786, 1823, 1829, 1998, 2006, 2146, 2183, 2216, 2268, 2283, 2321, 2490, 2528, 2550, 2558, 2606, 2625, 2786, 2878, 2895, 2976, 3084, 3112, 3120, 3157, 3166, 3225, 3243, 3256, 3280], 'AZ': [22, 33, 94, 97, 105, 114, 125, 168, 187, 211, 213, 248, 304, 329, 348, 374, 417, 428, 456, 468, 478, 566, 598, 717, 790, 796, 799, 891, 965, 1235, 1262, 1298, 1329, 1357, 1385, 1399, 1475, 1501, 1555, 1573, 1635, 1718, 1719, 1870, 1899, 1939, 1988, 2078, 2326, 2408, 2491, 2512, 2812, 2841, 2890, 2995, 3047, 3099, 3101, 3153, 3186, 3235, 3284, 3328], 'CA': [61, 131, 356, 372, 496, 654, 655, 765, 862, 954, 1038, 1158, 1174, 1290, 
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1       OH             107        415  371-7191         no        yes
# 3       OH              84        408  375-9999        yes         no
# 152     OH              65        408  336-7600         no         no
# 156     OH              83        415  370-9116         no         no
# 231     OH              63        415  410-3719        yes        yes
# ...    ...             ...        ...       ...        ...        ...
# 3249    OH             160        415  337-9326         no         no
# 3251    OH              88        408  354-3040         no         no
# 3286    OH             106        415  352-2270         no        yes
# 3325    OH              78        408  368-8555         no         no
# 3326    OH              96        415  347-6812         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 1                26     161.6        123       27.47  ...        103
# 3                 0     299.4         71       50.90  ...         88
# 152               0     187.9        116       31.94  ...        117
# 156               0     337.4        120       57.36  ...        116
# 231              36     199.0        110       33.83  ...        111
# ...             ...       ...        ...         ...  ...        ...
# 3249              0     206.3         66       35.07  ...        109
# 3251              0     274.6        105       46.68  ...        121
# 3286             30     220.1        105       37.42  ...        109
# 3325              0     193.4         99       32.88  ...         88
# 3326              0     106.6        128       18.12  ...         87
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 1          16.62       254.4          103         11.45       13.7
# 3           5.26       196.9           89          8.86        6.6
# 152        13.40       227.3           86         10.23        7.5
# 156        19.33       153.9          114          6.93       15.8
# 231        24.76       197.6           92          8.89       11.0
# ...          ...         ...          ...           ...        ...
# 3249       20.49       227.8          102         10.25       11.7
# 3251       13.69       194.4          123          8.75        9.2
# 3286       18.89       158.4           96          7.13       13.1
# 3325        9.94       243.3          109         10.95        9.3
# 3326       24.21       178.9           92          8.05       14.9
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 1              3         3.70               1  False.
# 3              7         1.78               2  False.
# 152            6         2.03               1  False.
# 156            7         4.27               0   True.
# 231            6         2.97               1  False.
# ...          ...          ...             ...     ...
# 3249           6         3.16               0  False.
# 3251           4         2.48               2  False.
# 3286           8         3.54               0  False.
# 3325           4         2.51               2  False.
# 3326           7         4.02               1  False.
#
# [78 rows x 21 columns]

# %%
df.groupby(['State', 'VMail Plan']).groups
# Out:
# {('AK', 'no'): [95, 181, 339, 350, 353, 505, 550, 657, 684, 718, 719, 812, 950, 1024, 1054, 1094, 1162, 1224, 1417, 1589, 1803, 1987, 2071, 2083, 2101, 2270, 2367, 2418, 2475, 2571, 2627, 2807, 2929, 3137, 3241, 3283], ('AK', 'yes'): [36, 38, 138, 282, 953, 1260, 1342, 1682, 1884, 2222, 2265, 2269, 2752, 2902, 3088, 3236], ('AL', 'no'): [5, 112, 135, 169, 219, 239, 288, 332, 450, 491, 497, 531, 590, 788, 805, 822, 843, 859, 934, 949, 1015, 1090, 1104, 1129, 1152, 1274, 1428, 1464, 1613, 1662, 1780, 1839, 1902, 2081, 2135, 2155, 2172, 2180, 2317, 2329, 2334, 2446, 2595, 2634, 2644, 2699, 2738, 2748, 2749, 2827, 2845, 2939, 3017, 3048, 3058, 3078, 3128, 3139, 3180], ('AL', 'yes'): [272, 278, 326, 469, 514, 540, 750, 776, 958, 1026, 1131, 1661, 1767, 2212, 2348, 2494, 2601, 2858, 2992, 3095, 3306], ('AR', 'no'): [42, 92, 134, 178, 297, 352, 475, 585, 696, 911, 960, 1023, 1226, 1484, 1536, 1543, 1601, 1639, 1786, 1998, 2146, 2183, 2216, 2283, 2321, 2490, 2528, 2550, 2558, 2606, 2625, 2895, 2976, 3084, 3112, 3157, 3166, 3225, 3243, 3256, 3280], ('AR', 'yes'): [351, 440, 442, 652, 956, 1320, 1596, 1823, 1829, 2006, 2268, 2786, 2878, 3120], ('AZ', 'no'): [22, 33, 94, 97, 105, 114, 125, 187, 211, 248, 304, 329,
1470, 1665, 2254, 2257, 2540, 3077], ('GA', 'no'): [40, 340, 448, 483, 484, 552, 629, 835, 881, 959, 1017, 1058, 1150, 1177, 1249, 1295, 1447, 1488, 1680, 1789, 1922, 2043, 2132, 2264, 2417, 2445, 2578, 2580, 2584, 2942, 2953, 3098, 3107, 3121, 3320], ('GA', 'yes'): [35, 83, 166, 316, 327, 400, 477, 665, 669, 716 ...

# %% [markdown]
# ## Agregación de datos agrupados

# %%
df.groupby(['State', 'VMail Plan'])[['Day Mins', 'Day Calls']].sum()
# Out:
#                   Day Mins  Day Calls
# State VMail Plan
# AK    no            6358.2       3338
#       yes           2917.8       1616
# AL    no           10733.2       5858
#       yes           4147.6       2070
# AR    no            6908.4       4168
# ...                    ...        ...
# WI    yes           4260.1       2164
# WV    no           13343.3       8224
#       yes           5095.5       2777
# WY    no           10775.0       6103
#       yes           3098.1       1768
#
# [102 rows x 2 columns]

# %%
df.groupby(['State', 'VMail Plan'])[['Day Mins', 'Day Calls']].max()
# Out:
#                   Day Mins  Day Calls
# State VMail Plan
# AK    no             278.4        129
#       yes            278.0        128
# AL    no             270.0        139
#       yes            308.0        135
# AR    no             268.0        145
# ...                    ...        ...
# WI    yes            248.6        140
# WV    no             312.0        147
#       yes            266.7        158
# WY    no             296.0        158
#       yes            270.3        135
#
# [102 rows x 2 columns]

# %%
df.groupby(['State', 'VMail Plan'])[['Day Mins', 'Day Calls']].min()
# Out:
#                   Day Mins  Day Calls
# State VMail Plan
# AK    no              58.2         55
#       yes             75.8         60
# AL    no              86.8         62
#       yes             68.7         63
# AR    no              55.3         56
# ...                    ...        ...
# WI    yes             69.1         54
# WV    no              58.0         57
#       yes             64.9         40
# WY    no              82.7         55
#       yes             25.9         45
#
# [102 rows x 2 columns]

# %%
df.groupby(['State', 'VMail Plan'])[['Day Mins', 'Day Calls']].count()
# Out:
#                   Day Mins  Day Calls
# State VMail Plan
# AK    no                36         36
#       yes               16         16
# AL    no                59         59
#       yes               21         21
# AR    no                41         41
# ...                    ...        ...
# WI    yes               23         23
# WV    no                77         77
#       yes               29         29
# WY    no                59         59
#       yes               18         18
#
# [102 rows x 2 columns]

# %%
df.groupby(['State', 'VMail Plan'])[['Day Mins', 'Day Calls']].mean()
# Out:
#                     Day Mins   Day Calls
# State VMail Plan
# AK    no          176.616667   92.722222
#       yes         182.362500  101.000000
# AL    no          181.918644   99.288136
#       yes         197.504762   98.571429
# AR    no          168.497561  101.658537
# ...                      ...         ...
# WI    yes         185.221739   94.086957
# WV    no          173.289610  106.805195
#       yes         175.706897   95.758621
# WY    no          182.627119  103.440678
#       yes         172.116667   98.222222
#
# [102 rows x 2 columns]

# %% [markdown]
# ## Filtrado de datos

# %%
df.groupby(['State', 'VMail Plan'])[['Day Mins']].filter(lambda x: x.sum() > 190)
# Out:
#       Day Mins
# 0        265.1
# 1        161.6
# 2        243.4
# 3        299.4
# 4        166.7
# ...        ...
# 3328     156.2
# 3329     231.1
# 3330     180.8
# 3331     213.8
# 3332     234.4
#
# [3333 rows x 1 columns]

# %% [markdown]
# ## Transformación de variables

# %%
zscore = lambda x: (x - x.mean()) / x.std()

# %%
df.groupby(['State', 'VMail Plan'])[['Day Mins']].transform(zscore)
# Out:
#       Day Mins
# 0     1.716676
# 1    -0.465606
# 2     0.912876
# 3     1.882759
# 4    -0.246018
# ...        ...
# 3328 -0.099236
# 3329  1.092481
# 3330  0.255666
# 3331  0.611077
# 3332  0.594044
#
# [3333 rows x 1 columns]
